# %%
import pandas as pd
import tensorflow as tf
import numpy as np

# %%
data=pd.read_excel('sinyal_indihome_pandemi.xlsx')
data
# Out:
#                                                   Tweet
# 0        Woy ini sinyal lu bapuk banget anjir @IndiHome
# 1     Parah sinyal wifi indihome gak jelas banget ma...
# 2     indihome kenapa ini? beberapa hari sinyal gw j...
# 3                          @IndiHome sinyal jelek terus
# 4     @IndiHome sinyal WiFi nya koq gangguan ga ada ...
# ...                                                 ...
# 4992  @MPrasetyoN Kak Prasetyo, maaf ya bikin ga nya...
# 4993               sinyal lu jelek bgt si anj @IndiHome
# 4994  @meidinanm Hallo Meidina, maaf ya jadi bikin t...
# 4995  @firdaus72332200 Selamat siang Kak Firdaus, mo...
# 4996  @jiharkafm kalo gue begini apakah sinyal indih...
#
# [4997 rows x 1 columns]

# %%
label=pd.read_csv('HASIL_LABELING_PANDEMI(BARU).csv')
label
# Out:
#                                        Tweet_translated  Compound_Score  \
# 0     Wow, this is a sign that you are really good a...          0.7902
# 1     It's bad that the Indihome wifi signal isn't r...         -0.7096
# 2     indihome why is this? some days my signal is r...         -0.5849
# 3                    @IndiHome the bad signal continues         -0.5423
# 4     @IndiHome the WiFi signal, how come there's no...         -0.2960
# ...                                                 ...             ...
# 4992  @MPrasetyoN Sis Prasetyo, sorry for making the...         -0.5873
# 4993            Your signal is really bad anj @IndiHome         -0.5849
# 4994  @meidinanm Hallo Meidina, sorry this made me u...         -0.6808
# 4995  @firdaus72332200 Good afternoon Firdaus, I apo...         -0.1779
# 4996  @jiharkafm If I do this, can the Indihome sign...          0.5106
#
#       Sentiments
# 0              1
# 1              0
# 2              0
# 3              0
# ...

# %%
label['Tweet_translated']=data['Tweet']
label
# Out:
#                                        Tweet_translated  Compound_Score  \
# 0        Woy ini sinyal lu bapuk banget anjir @IndiHome          0.7902
# 1     Parah sinyal wifi indihome gak jelas banget ma...         -0.7096
# 2     indihome kenapa ini? beberapa hari sinyal gw j...         -0.5849
# 3                          @IndiHome sinyal jelek terus         -0.5423
# 4     @IndiHome sinyal WiFi nya koq gangguan ga ada ...         -0.2960
# ...                                                 ...             ...
# 4992  @MPrasetyoN Kak Prasetyo, maaf ya bikin ga nya...         -0.5873
# 4993               sinyal lu jelek bgt si anj @IndiHome         -0.5849
# 4994  @meidinanm Hallo Meidina, maaf ya jadi bikin t...         -0.6808
# 4995  @firdaus72332200 Selamat siang Kak Firdaus, mo...         -0.1779
# 4996  @jiharkafm kalo gue begini apakah sinyal indih...          0.5106
#
#       Sentiments
# 0              1
# 1              0
# 2              0
# 3              0
# ...

# %%
label.drop(index=label[label['Sentiments']=='2'].index, inplace=True)
label
# Out:
#                                        Tweet_translated  Compound_Score  \
# 0        Woy ini sinyal lu bapuk banget anjir @IndiHome          0.7902
# 1     Parah sinyal wifi indihome gak jelas banget ma...         -0.7096
# 2     indihome kenapa ini? beberapa hari sinyal gw j...         -0.5849
# 3                          @IndiHome sinyal jelek terus         -0.5423
# 4     @IndiHome sinyal WiFi nya koq gangguan ga ada ...         -0.2960
# ...                                                 ...             ...
# 4992  @MPrasetyoN Kak Prasetyo, maaf ya bikin ga nya...         -0.5873
# 4993               sinyal lu jelek bgt si anj @IndiHome         -0.5849
# 4994  @meidinanm Hallo Meidina, maaf ya jadi bikin t...         -0.6808
# 4995  @firdaus72332200 Selamat siang Kak Firdaus, mo...         -0.1779
# 4996  @jiharkafm kalo gue begini apakah sinyal indih...          0.5106
#
#       Sentiments
# 0              1
# 1              0
# 2              0
# 3              0
# ...

# %%
label
# Out:
#                                        Tweet_translated  Compound_Score  \
# 0              acak acak rambut beranta sinyal indihome         -0.3612
# 1     access point wifi indihome device jarak wirele...          0.3612
# 2     aco sinyal gilir nagih bayar saja cerewetny am...         -0.0387
# 3                                   aco sinyal indihome          0.0000
# 4                                aco sinyal parah benar         -0.3818
# ...                                                 ...             ...
# 4844  yuk yuk bikin emosi menang mahal doang sinyal ...          0.7650
# 4845  yups pakai by ngikut down sinyal pakai sinyal ...          0.0000
# 4846  yutupan niheh sinyal wifinya gin buffering mul...         -0.4215
# 4847  zoom jam sinyal disconneted mulu zoom cabut in...          0.0000
# 4848  zoom sama indihome kenapa sampai kelas mtk jug...          0.0000
#
#       Sentiments
# 0              0
# 1              1
# 2              0
# 3              2
# ...

# %%
label.to_csv('HASIL_LABELING_PANDEMI(UPDATE).csv', encoding='utf-8', index=False)
